# %%
pip install mne
# Out:
# Requirement already satisfied: mne in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (1.1.1)
# Requirement already satisfied: packaging in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from mne) (21.0)
# Requirement already satisfied: matplotlib in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from mne) (3.4.3)
# Requirement already satisfied: tqdm in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from mne) (4.62.3)
# Requirement already satisfied: decorator in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from mne) (5.1.0)
# Requirement already satisfied: jinja2 in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from mne) (2.11.3)
# Requirement already satisfied: numpy>=1.15.4 in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from mne) (1.20.3)
# Requirement already satisfied: pooch>=1.5 in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from mne) (1.6.0)
# Requirement already satisfied: scipy>=1.1.0 in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from mne) (1.7.1)
# Requirement already satisfied: requests>=2.19.0 in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from pooch>=1.5->mne) (2.26.0)
# Requirement already satisfied: appdirs>=1.3.0 in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from pooch>=1.5->mne) (1.4.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from packaging->mne) (3.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from jinja2->mne) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mne) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mne) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mne) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->mne) (8.4.0)
# Requirement already satisfied: six in /Users/josangmin/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->mne) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import mne
import numpy as np
import os
import pickle

# %%
def sample_process(root_folder, k, N, epoch_sec, train_test_val, index):
    for i, j in enumerate(index):
        if i % N == k:
            if k == 0:
                print ('Progress: {} / {}'.format(i, len(index)))

            # load signal "X" part
            data = mne.io.read_raw_edf(root_folder + '/' + list(filter(lambda x: (x[:6] == j) and ('PSG' in x), os.listdir(root_folder)))[0])
            X = data.get_data()[:2, :]
            
            # load label "Y" part
            ann = mne.read_annotations(root_folder + '/' + list(filter(lambda x: (x[:6] == j) and ('Hypnogram' in x), os.listdir(root_folder)))[0])
            labels = []
            for dur, des in zip(ann.duration, ann.description):
                for i in range(int(dur) // 30):
                    labels.append(des[-1])

            # slice the EEG signals into non-overlapping windows, window size = sampling rate per second * second time = 100 * windowsize
            for slice_index in range(X.shape[1] // (100 * epoch_sec)):
                # ingore the no labels
                if labels[slice_index] == '?':
                    continue
                path = './SLEEP_data/cassette_processed/{}/'.format(train_test_val) + 'cassette-' + j + '-' + str(slice_index) + '.pkl'
                pickle.dump({'X': X[:, slice_index * 100 * epoch_sec: (slice_index+1) * 100 * epoch_sec], \
                    'y': labels[slice_index]}, open(path, 'wb'))

# %%
from pyedflib import highlevel
import numpy as np
import glob

path1 = '/Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette'
path2 = '/Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-telemetry'
data_list_cassette = sorted(glob.glob(path1+'/**'))
data_list_telemetry = sorted(glob.glob(path2+'/**')) 

print('number of cattette files',len(data_list_cassette))
print('number of telemetry files',len(data_list_telemetry))
# Out:
# number of cattette files 306
# number of telemetry files 88

# %%
#First, investigate cassette files.
trains_SC = [x for x in data_list_cassette if x.endswith('PSG.edf')]
labels_SC= [x for x in data_list_cassette if x.endswith('Hypnogram.edf')]

trains_ST = [x for x in data_list_telemetry if x.endswith('PSG.edf')]
labels_ST= [x for x in data_list_telemetry if x.endswith('Hypnogram.edf')]

print('number of SC_train samples:',len(trains_SC))
print('number of SC_labels:',len(labels_SC))
print('number of ST_train samples:',len(trains_ST))
print('number of ST_labels:',len(labels_ST))
# Out:
# number of SC_train samples: 153
# number of SC_labels: 153
# number of ST_train samples: 44
# number of ST_labels: 44

# %%
for i in range(len(trains_SC)):
    print(trains_SC[i].split('/')[-1].split('-')[0])
    print(labels_SC[i].split('/')[-1].split('-')[0])
    print('-----')
# Out:
# SC4001E0
# SC4001EC
# -----
# SC4002E0
# SC4002EC
# -----
# SC4011E0
# SC4011EH
# -----
# SC4012E0
0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
X.shape # EEG signal
# Out:
# (2, 7950000)

# %%
ann = mne.read_annotations(labels_SC[0])
print(ann.duration)
print('------')
print(ann.description)
# Out:
# [3.063e+04 1.200e+02 3.900e+02 3.000e+01 3.000e+01 1.500e+02 3.000e+01
#  6.000e+01 6.000e+01 3.000e+01 1.200e+02 3.000e+01 1.200e+02 3.000e+01
#  6.000e+01 6.000e+01 1.200e+02 3.000e+01 3.000e+01 1.200e+02 2.100e+02
#  3.000e+01 6.000e+01 1.200e+02 3.000e+01 1.500e+02 6.000e+01 3.000e+01
#  3.000e+01 3.000e+01 1.200e+02 1.500e+02 3.000e+01 3.000e+01 6.000e+01
#  3.000e+01 9.000e+01 1.890e+03 3.000e+01 2.100e+02 6.000e+01 9.000e+01
#  1.500e+02 3.000e+01 8.700e+02 1.800e+02 2.400e+02 3.000e+01 1.200e+02
#  9.000e+01 3.000e+01 9.300e+02 3.000e+01 3.000e+01 6.000e+01 3.000e+01
#  3.000e+01 3.000e+01 3.000e+01 3.000e+01 3.000e+01 1.500e+02 6.000e+01
#  9.000e+01 6.000e+01 3.000e+01 3.000e+01 6.000e+01 6.000e+01 1.800e+02
#  6.000e+01 3.000e+01 3.000e+01 2.700e+02 3.000e+01 6.000e+01 3.000e+01
#  2.100e+02 3.000e+01 6.000e+01 3.000e+01 1.800e+02 8.700e+02 3.000e+01
#  6.000e+01 3.000e+01 1.200e+02 8.700e+02 3.000e+01 3.000e+01 3.000e+01
#  3.000e+02 3.000e+01 3.900e+02 3.000e+01 3.000e+01 3.000e+01 3.000e+01
#  1.800e+02 9.000e+01 3.000e+01 2.100e+02 6.000e+01 3.000e+01 3.000e+01
#  1.800e+02 6.000e+01 6.000e+01 6.000e+01 1.200e+02 1.200e+02 3.000e+01
#  3.000e+01 3.000e+01 2.400e+02 3.000e+01 5.100e+02 3.000e+01 1.200e+02
#  4.800e+02 9.000e+01 3.000e+01 1.200e+02 6.900e+02 6.000e+01 3.000e+01
#  9.900e+02 3.000e+01 3.000e+01 9.000e+01 1.200e+02 6.000e+01 6.000e+01
#  3.000e+01 3.000e+01 3.000e+01 3.000e+01 1.200e+02 2.100e+02 3.000e+01
#  1.200e+02 6.000e+01 9.900e+02 3.000e+01 1.500e+02 2.700e+02 5.100e+02
#  9.000e+01 3.000e+02 3.000e+01 5.400e+02 1.500e+02 2.724e+04 6.900e+03]
# ------
# ['Sleep stage W' 'Sleep stage 1' 'Sleep stage 2' 'Sleep stage 3'
#  'Sleep stage 2' 'Sleep stage 3' 'Sleep stage 4' 'Sleep stage 3'
#  'Sleep stage 4' 'Sleep stage 3' 'Sleep stage 4' 'Sleep stage 3'
#  'Sleep stage 4' 'Sleep stage W' 'Sleep stage 3' 'Sleep stage 2'
#  'Sleep stage 3' 'Sleep stage 4' 'Sleep stage 3' 'Sleep stage 4'
#  'Sleep stage 2' 'Sleep stage 3' 'Sleep stage 2' 'Sleep stage 3'
#  'Sleep stage 1' 'Sleep stage 2' 'Sleep stage 3' 'Sleep stage 2'
#  'Sleep stage 3' 'Sleep stage 2' 'Sleep stage 3' 'Sleep stage 4'
#  'Sleep stage 3' 'Sleep stage 2' 'Sleep stage 3' 'Sleep stage 4'
#  'Sleep stage 3' 'Sleep stage 4' 'Sleep stage 1' 'Sleep stage 3'
#  'Sleep stage 2' 'Sleep stage 3' 'Sleep stage 2' 'Sleep stage 3'
#  'Sleep stage R' 'Sleep stage 1' 'Sleep stage 2' 'Sleep stage 3'
#  'Sleep stage 1' 'Sleep stage 2' 'Sleep stage 1' 'Sleep stage 2'
#  'Sleep stage 3' 'Sleep stage 2' 'Sleep stage 3' 'Sleep stage 4'
#  'Sleep stage 3' 'Sleep stage 4' 'Sleep stage 3' 'Sleep stage 4'
#  'Sleep stage 3' 'Sleep stage 2' 'Sleep stage 3' 'Sleep stage 4'
#  'Sleep stage 3' 'Sleep stage 4' 'Sleep stage 3' 'Sleep stage 4'
#  'Sleep stage 3' 'Sleep stage 4' 'Sleep stage 3' 'Sleep stage 4'
#  'Sleep stage 3' 'Sleep stage 4' 'Sleep stage 1' 'Sleep stage 2'
#  'Sleep stage 1' 'Sleep stage 2' 'Sleep stage 1' 'Sleep stage 2'
#  'Sleep stage 1' 'Sleep stage 2' 'Sleep stage R' 'Sleep stage 2'
#  'Sleep stage 1' 'Sleep stage W' 'Sleep stage 1' 'Sleep stage 2'
#  'Sleep stage 1' 'Sleep stage 2' 'Sleep stage 1' 'Sleep stage 2'
#  'Sleep stage 3' 'Sleep stage 2' 'Sleep stage 3' 'Sleep stage 2'
#  'Sleep stage 3' 'Sleep stage 2' 'Sleep stage 3' 'Sleep stage 4'
#  'Sleep stage 3' 'Sleep stage 2' 'Sleep stage 3' 'Sleep stage 2'
#  'Sleep stage 4' 'Sleep stage 3' 'Sleep stage 4' 'Sleep stage 3'
#  'Sleep stage 4' 'Sleep stage 3' 'Sleep stage 2' 'Sleep stage 3'
#  'Sleep stage 4' 'Sleep stage 2' 'Sleep stage R' 'Sleep stage 1'
#  'Sleep stage R' 'Sleep stage W' 'Sleep stage 1' 'Sleep stage W'
#  'Sleep stage 1' 'Sleep stage W' 'Sleep stage 1' 'Sleep stage 2'
#  'Sleep stage W' 'Sleep stage 1' 'Sleep stage 2' 'Sleep stage 3'
#  'Sleep stage 2' 'Sleep stage 3' 'Sleep stage 2' 'Sleep stage 3'
#  'Sleep stage 2' 'Sleep stage 3' 'Sleep stage 2' 'Sleep stage 3'
#  'Sleep stage 2' 'Sleep stage 3' 'Sleep stage 2' 'Sleep stage 3'
#  'Sleep stage 2' 'Sleep stage 1' 'Sleep stage R' 'Sleep stage W'
#  'Sleep stage 1' 'Sleep stage R' 'Sleep stage W' 'Sleep stage 1'
#  'Sleep stage W' 'Sleep stage 1' 'Sleep stage W' 'Sleep stage 1'
#  'Sleep stage W' 'Sleep stage ?']

# %%
labels = []
for dur, des in zip(ann.duration, ann.description):
    for i in range(int(dur) // 30):
        labels.append(des[-1])

# %%
sum(ann.duration)*100
# Out:
# 8640000.0

# %%
print(len(labels))
print(7950000//(100*30))
# Out:
# 2880
# 2650

# %%
header = highlevel.read_edf(labels_SC[0])[2]['annotations']
print(header)
# Out:
# [[0.0, 30630.0, 'Sleep stage W'], [30630.0, 120.0, 'Sleep stage 1'], [30750.0, 390.0, 'Sleep stage 2'], [31140.0, 30.0, 'Sleep stage 3'], [31170.0, 30.0, 'Sleep stage 2'], [31200.0, 150.0, 'Sleep stage 3'], [31350.0, 30.0, 'Sleep stage 4'], [31380.0, 60.0, 'Sleep stage 3'], [31440.0, 60.0, 'Sleep stage 4'], [31500.0, 30.0, 'Sleep stage 3'], [31530.0, 120.0, 'Sleep stage 4'], [31650.0, 30.0, 'Sleep stage 3'], [31680.0, 120.0, 'Sleep stage 4'], [31800.0, 30.0, 'Sleep stage W'], [31830.0, 60.0, 'Sleep stage 3'], [31890.0, 60.0, 'Sleep stage 2'], [31950.0, 120.0, 'Sleep stage 3'], [32070.0, 30.0, 'Sleep stage 4'], [32100.0, 30.0, 'Sleep stage 3'], [32130.0, 120.0, 'Sleep stage 4'], [32250.0, 210.0, 'Sleep stage 2'], [32460.0, 30.0, 'Sleep stage 3'], [32490.0, 60.0, 'Sleep stage 2'], [32550.0, 120.0, 'Sleep stage 3'], [32670.0, 30.0, 'Sleep stage 1'], [32700.0, 150.0, 'Sleep stage 2'], [32850.0, 60.0, 'Sleep stage 3'], [32910.0, 30.0, 'Sleep stage 2'], [32940.0, 30.0, 'Sleep stage 3'], [32970.0, 30.0, 'Sleep stage 2'], [33000.0, 120.0, 'Sleep stage 3'], [33120.0, 150.0, 'Sleep stage 4'], [33270.0, 30.0, 'Sleep stage 3'], [33300.0, 30.0, 'Sleep stage 2'], [33330.0, 60.0, 'Sleep stage 3'], [33390.0, 30.0, 'Sleep stage 4'], [33420.0, 90.0, 'Sleep stage 3'], [33510.0, 1890.0, 'Sleep stage 4'], [35400.0, 30.0, 'Sleep stage 1'], [35430.0, 210.0, 'Sleep stage 3'], [35640.0, 60.0, 'Sleep stage 2'], [35700.0, 90.0, 'Sleep stage 3'], [35790.0, 150.0, 'Sleep stage 2'], [35940.0, 30.0, 'Sleep stage 3'], [35970.0, 870.0, 'Sleep stage R'], [36840.0, 180.0, 'Sleep stage 1'], [37020.0, 240.0, 'Sleep stage 2'], [37260.0, 30.0, 'Sleep stage 3'], [37290.0, 120.0, 'Sleep stage 1'], [37410.0, 90.0, 'Sleep stage 2'], [37500.0, 30.0, 'Sleep stage 1'], [37530.0, 930.0, 'Sleep stage 2'], [38460.0, 30.0, 'Sleep stage 3'], [38490.0, 30.0, 'Sleep stage 2'], [38520.0, 60.0, 'Sleep stage 3'], [38580.0, 30.0, 'Sleep stage 4'], [38610.0, 30.0, 'Sleep stage 3'], [38640.0, 30.0, 'Sleep stage 4'], [38670.0, 30.0, 'Sleep stage 3'], [38700.0, 30.0, 'Sleep stage 4'], [38730.0, 30.0, 'Sleep stage 3'], [38760.0, 150.0, 'Sleep stage 2'], [38910.0, 60.0, 'Sleep stage 3'], [38970.0, 90.0, 'Sleep stage 4'], [39060.0, 60.0, 'Sleep stage 3'], [39120.0, 30.0, 'Sleep stage 4'], [39150.0, 30.0, 'Sleep stage 3'], [39180.0, 60.0, 'Sleep stage 4'], [39240.0, 60.0, 'Sleep stage 3'], [39300.0, 180.0, 'Sleep stage 4'], [39480.0, 60.0, 'Sleep stage 3'], [39540.0, 30.0, 'Sleep stage 4'], [39570.0, 30.0, 'Sleep stage 3'], [39600.0, 270.0, 'Sleep stage 4'], [39870.0, 30.0, 'Sleep stage 1'], [39900.0, 60.0, 'Sleep stage 2'], [39960.0, 30.0, 'Sleep stage 1'], [39990.0, 210.0, 'Sleep stage 2'], [40200.0, 30.0, 'Sleep stage 1'], [40230.0, 60.0, 'Sleep stage 2'], [40290.0, 30.0, 'Sleep stage 1'], [40320.0, 180.0, 'Sleep stage 2'], [40500.0, 870.0, 'Sleep stage R'], [41370.0, 30.0, 'Sleep stage 2'], [41400.0, 60.0, 'Sleep stage 1'], [41460.0, 30.0, 'Sleep stage W'], [41490.0, 120.0, 'Sleep stage 1'], [41610.0, 870.0, 'Sleep stage 2'], [42480.0, 30.0, 'Sleep stage 1'], [42510.0, 30.0, 'Sleep stage 2'], [42540.0, 30.0, 'Sleep stage 1'], [42570.0, 300.0, 'Sleep stage 2'], [42870.0, 30.0, 'Sleep stage 3'], [42900.0, 390.0, 'Sleep stage 2'], [43290.0, 30.0, 'Sleep stage 3'], [43320.0, 30.0, 'Sleep stage 2'], [43350.0, 30.0, 'Sleep stage 3'], [43380.0, 30.0, 'Sleep stage 2'], [43410.0, 180.0, 'Sleep stage 3'], [43590.0, 90.0, 'Sleep stage 4'], [43680.0, 30.0, 'Sleep stage 3'], [43710.0, 210.0, 'Sleep stage 2'], [43920.0, 60.0, 'Sleep stage 3'], [43980.0, 30.0, 'Sleep stage 2'], [44010.0, 30.0, 'Sleep stage 4'], [44040.0, 180.0, 'Sleep stage 3'], [44220.0, 60.0, 'Sleep stage 4'], [44280.0, 60.0, 'Sleep stage 3'], [44340.0, 60.0, 'Sleep stage 4'], [44400.0, 120.0, 'Sleep stage 3'], [44520.0, 120.0, 'Sleep stage 2'], [44640.0, 30.0, 'Sleep stage 3'], [44670.0, 30.0, 'Sleep stage 4'], [44700.0, 30.0, 'Sleep stage 2'], [44730.0, 240.0, 'Sleep stage R'], [44970.0, 30.0, 'Sleep stage 1'], [45000.0, 510.0, 'S ...

# %% [markdown]
# duration이 0초부터 시작.
# 끝에 잔여 시긴호가 있는 걸로 확인

# %%
for slice_index in range(X.shape[1] // (100 * 30)):
    # ingore the no labels
    if labels[slice_index] == '?':
        continue
    print(X[:, slice_index * 100 * 30: (slice_index+1) * 100 * 30].shape)
    print(labels[slice_index])
    if slice_index >= 10:
        break
# Out:
# (2, 3000)
# W
# (2, 3000)
# W
# (2, 3000)
# W
# (2, 3000)
# W
# (2, 3000)
# W
# (2, 3000)
# W
# (2, 3000)
# W
# (2, 3000)
# W
# (2, 3000)
# W
# (2, 3000)
# W
# (2, 3000)
# W

# %% [markdown]
# annotaion과 그에 해당하는 신호들을 추출 가능!
#
# ----

# %% [markdown]
# 다양한 dataset을 가지고 SSL을 하고자 하는데, sampling rate를 200Hz로 통일 하고자 함.
# sampling rate가 200Hz가 정답이 아님. 데이터를 불러올때 마다 원하는 sampling rate로 불러 올 수 있는데(mne.fikter.resample()), 이 과정이 오래걸려서 애초에 200Hz로 저장하려고 함.

# %%
X = data.get_data()[:2,:]
X1 = mne.filter.resample(X, up = 2.0) # upsampling to 200Hz  
print(X.shape)
print(X1.shape[1]/2)
# Out:
# (2, 7950000)
# 7950000.0

# %%
import os
for i in range(len(trains_SC)):
    print(i)
    subjetc_id = trains_SC[i].split('/')[-1].split('-')[0]
    
    # load signal and upsampling
    data = mne.io.read_raw_edf(trains_SC[i])
    data = data.get_data()[:2,:]
    data = mne.filter.resample(data, up = 2.0) # upsampling to 200Hz  
    
    # load annotaion
    ann = mne.read_annotations(labels_SC[i])
    labels = []
    for dur, des in zip(ann.duration, ann.description):
        for i in range(int(dur) // 30):
            labels.append(des[-1])

    for slice_index in range(data.shape[1] // (200 * 30)): # 200Hz, 30epochs
    # ingore the no labels
        if labels[slice_index] == '?':
            continue
            
        
        adress = '/Users/josangmin/EEG/Sleep_edfx_30s_200Hz/SC'
        if not os.path.exists(adress+'/data/{}'.format(subjetc_id)):
            os.makedirs(adress +'/data/{}'.format(subjetc_id))
            data_adress = adress +'/data/{}'.format(subjetc_id)
            os.makedirs(adress + '/label/{}'.format(subjetc_id))
            label_adress = adress +'/label/{}'.format(subjetc_id)
            
        data_path = data_adress +'/data'+ str(subjetc_id) + '_' + str(slice_index) + '.pkl'
        label_path = label_adress + '/label' + str(subjetc_id) + '_' + str(slice_index) + '.pkl'
        X = data[:, slice_index * 200 * 30: (slice_index+1) * 200 * 30]
        with open(file = data_path, mode='wb') as f:
            pickle.dump(X, f)
        with open(file = label_path, mode='wb') as f:
            pickle.dump(labels[slice_index], f)
# Out:
# 0
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4001E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 1
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4002E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 2
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4011E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 3
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4012E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 4
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4021E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 5
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4022E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 6
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4031E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 7
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4032E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 8
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4041E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 9
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4042E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 10
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4051E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 11
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4052E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 12
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4061E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 13
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4062E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 14
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4071E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 15
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4072E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 16
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4081E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 17
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4082E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 18
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4091E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 19
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4092E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 20
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4101E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 21
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4102E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 22
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4111E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 23
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4112E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 24
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4121E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 25
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4122E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 26
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4131E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 27
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4141E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 28
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4142E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 29
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4151E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 30
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4152E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 31
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4161E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 32
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4162E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 33
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4171E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 34
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4172E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 35
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4181E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 36
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4182E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 37
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4191E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 38
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4192E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 39
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4201E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 40
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4202E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 41
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4211E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 42
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4212E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 43
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4221E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 44
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4222E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 45
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4231E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 46
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4232E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 47
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4241E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 48
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4242E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 49
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4251E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 50
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4252E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 51
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4261F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 52
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4262F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 53
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4271F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 54
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4272F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 55
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4281G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 56
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4282G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 57
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4291G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 58
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4292G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 59
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4301E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 60
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4302E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 61
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4311E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 62
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4312E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 63
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4321E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 64
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4322E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 65
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4331F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 66
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4332F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 67
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4341F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 68
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4342F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 69
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4351F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 70
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4352F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 71
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4362F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 72
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4371F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 73
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4372F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 74
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4381F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 75
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4382F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 76
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4401E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 77
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4402E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 78
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4411E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 79
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4412E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 80
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4421E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 81
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4422E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 82
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4431E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 83
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4432E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 84
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4441E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 85
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4442E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 86
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4451F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 87
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4452F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 88
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4461F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 89
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4462F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 90
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4471F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 91
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4472F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 92
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4481F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 93
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4482F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 94
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4491G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 95
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4492G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 96
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4501E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 97
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4502E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 98
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4511E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 99
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4512E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 100
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4522E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 101
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4531E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 102
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4532E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 103
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4541F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 104
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4542F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 105
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4551F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 106
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4552F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 107
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4561F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 108
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4562F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 109
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4571F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 110
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4572F0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 111
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4581G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 112
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4582G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 113
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4591G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 114
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4592G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 115
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4601E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 116
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4602E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 117
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4611E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 118
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4612E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 119
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4621E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 120
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4622E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 121
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4631E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 122
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4632E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 123
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4641E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 124
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4642E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 125
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4651E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 126
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4652E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 127
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4661E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 128
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4662E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 129
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4671G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 130
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4672G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 131
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4701E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 132
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4702E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 133
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4711E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 134
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4712E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 135
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4721E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 136
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4722E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 137
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4731E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 138
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4732E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 139
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4741E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 140
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4742E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 141
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4751E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 142
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4752E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 143
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4761E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 144
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4762E0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 145
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4771G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 146
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4772G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 147
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4801G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 148
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4802G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 149
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4811G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 150
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4812G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 151
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4821G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 152
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-cassette/SC4822G0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...

# %%
data_path = '/Users/josangmin/EEG/Sleep_edfx_30s_200Hz/SC/data/SC4001E0/' + 'dataSC4001E0_0.pkl'
with open(data_path, 'rb') as f:
    a = pickle.load(f)
a.shape
# Out:
# (2, 6000)

# %%
for i in range(len(trains_ST)):
    print(i)
    subjetc_id = trains_ST[i].split('/')[-1].split('-')[0]
    
    # load signal and upsampling
    data = mne.io.read_raw_edf(trains_ST[i])
    data = data.get_data()[:2,:]
    data = mne.filter.resample(data, up = 2.0) # upsampling to 200Hz  
    
    # load annotaion
    ann = mne.read_annotations(labels_ST[i])
    labels = []
    for dur, des in zip(ann.duration, ann.description):
        for i in range(int(dur) // 30):
            labels.append(des[-1])
    
    for slice_index in range(len(labels)): # 200Hz, 30epochs
    # ingore the no labels
        if labels[slice_index] == '?':
            continue
     
        adress = '/Users/josangmin/EEG/Sleep_edfx_30s_200Hz/ST'
        if not os.path.exists(adress+'/data/{}'.format(subjetc_id)):
            os.makedirs(adress +'/data/{}'.format(subjetc_id))
            data_adress = adress +'/data/{}'.format(subjetc_id)
            os.makedirs(adress + '/label/{}'.format(subjetc_id))
            label_adress = adress +'/label/{}'.format(subjetc_id)
            
        data_path = data_adress +'/data'+ str(subjetc_id) + '_' + str(slice_index) + '.pkl'
        label_path = label_adress + '/label' + str(subjetc_id) + '_' + str(slice_index) + '.pkl'
        X = data[:, slice_index * 200 * 30: (slice_index+1) * 200 * 30]
        with open(file = data_path, mode='wb') as f:
            pickle.dump(X, f)
        with open(file = label_path, mode='wb') as f:
            pickle.dump(labels[slice_index], f)
# Out:
# 0
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7011J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 1
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7012J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 2
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7021J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 3
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7022J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 4
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7041J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 5
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST7042J0-PSG.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# 6
# Extracting EDF parameters from /Users/josangmin/Downloads/sleep-edf-database-expanded-1.0.0/sleep-telemetry/ST